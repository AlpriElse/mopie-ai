# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import Session
from mopie_data.video_metadata_entity import VideoMetadataEntity

engine = create_engine("", echo=True)


with Session(engine) as session:
  test_metadata = VideoMetadataEntity("some-id", "some-title", 100, 1000, "2021-01-01")

  session.add_all([test_metadata])
  session.commit()
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pymysql/connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     806     if err is not None:
# --> 807         raise err
#     808     else:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# ...
